# %% [markdown]
# # Fieldwork transcription with Whisper
# Mount Google Drive, put the recordings in a folder there, and run the cells below. Runtime > Change runtime type > GPU.

# %%
# !pip install -q openai-whisper
# !apt-get -qq install ffmpeg
from google.colab import drive
drive.mount('/content/drive')

# %%
# !wget -q https://raw.githubusercontent.com/marinsisabella/whisper-fieldwork/main/transcribe.py
AUDIO = '/content/drive/MyDrive/fieldwork/audio'
OUT = '/content/drive/MyDrive/fieldwork/transcripts'
# !python transcribe.py --audio "$AUDIO" --out "$OUT" --lang pt --timestamps --model large
